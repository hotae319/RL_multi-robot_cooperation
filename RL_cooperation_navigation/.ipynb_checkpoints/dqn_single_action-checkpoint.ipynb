# %%
import numpy as np
import matplotlib.pyplot as plt
from time import sleep

class ENV:
    def __init__(self, map_size, obs_pos1, obs_pos2, robot_start_pos, goal_pos):
        self.map_size = map_size # integer
        self.obs_pos1 = obs_pos1 # [a,b], 2by1 list
        self.obs_pos2 = obs_pos2 # [a,b], 2by1 list
        self.goal_pos = goal_pos
        self.robot_pos1 = robot_start_pos[0:2] #[a,b] 2by1 list
        self.robot_pos2 = robot_start_pos[2:4]
        # set the walls
        self.fig = plt.figure()
        ax = plt.axes(xlim=(-0.5,self.map_size), ylim=(-0.5,self.map_size))  
        #self.render_env()
    def render_env(self):        
        # draw the obstacles and goal
        obs1 = plt.scatter(self.obs_pos1[0], self.obs_pos1[1], c='r', marker = 's', linewidths = 5) # have to check whether we can receive <list or np.array>        
        obs2 = plt.scatter(self.obs_pos2[0], self.obs_pos2[1], c='r', marker = 's', linewidths = 5)
        goal = plt.scatter(self.goal_pos[0], self.goal_pos[1], c='g', marker='x', linewidths = 4)
        # draw the robot                
        ro1 = plt.scatter(self.robot_pos1[0], self.robot_pos1[1], c='b', linewidths = 3)
        ro2 = plt.scatter(self.robot_pos2[0], self.robot_pos2[1], c='b', linewidths = 3)        
        self.fig.canvas.draw()   
        sleep(0.2)
        ro1.remove()
        ro2.remove()        
    def update(self, robot_current_pos):
        self.robot_pos1 = robot_current_pos[0:2]
        self.robot_pos2 = robot_current_pos[2:4]

# %% [markdown]
# ## DQN to cooperate 2 Mobile Manipulator
# * made by hotae
# * network includes one agent's action
# * full observable state

# %%
#Plotting setting
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import animation
from time import sleep

import numpy as np
import tensorflow as tf
import random
import dqn_cooperation
from collections import deque

import time
start = time.time()

# Create New environment with transition law
ACTION_NUM = 8
INPUT_SIZE = 10
OUTPUT_SIZE = ACTION_NUM
VEL = 1
TIME_GAP = 1
MAP_SIZE = 7
def annealing_epsilon(episode, min_e, max_e, target_episode):
    slope = (min_e - max_e) / (target_episode)
    intercept = max_e

    return max(min_e, slope * episode + intercept)

class new_env:     
    def create_env(self, arg_state=[0.,0.,1.0,1.0], g_pos=[5,5], obs_pos1=[0,7], obs_pos2=[7,0], obs_size=5):
        self.state = np.array(arg_state+g_pos+obs_pos1+obs_pos2) # reset
        self.n_state = np.array(arg_state+g_pos+obs_pos1+obs_pos2)
        self.obstacle_size = obs_size
        return self.state, self.obstacle_size
        
    def next_step(self, arg_state, arg_action):
        self._fail = False
        self.reward = 0
        # choose the action
        arg_action1 = arg_action 
        
        '''position update through action
        UP = 0, DOWN = 1, LEFT = 2, RIGHT = 3'''        
        # agent located on the first state 
        if arg_action1 == 0:
            self.n_state[0:4] = arg_state[0:4] + np.array([0,1,0,0])*VEL*TIME_GAP # move the 1st agent
        elif arg_action1 == 1:
            self.n_state[0:4] = arg_state[0:4] + np.array([0,-1,0,0])*VEL*TIME_GAP
        elif arg_action1 == 2:
            self.n_state[0:4] = arg_state[0:4] + np.array([-1,0,0,0])*VEL*TIME_GAP
        elif arg_action1 == 3:
            self.n_state[0:4] = arg_state[0:4] + np.array([1,0,0,0])*VEL*TIME_GAP
        elif arg_action1 == 4:
            self.n_state[0:4] = arg_state[0:4] + np.array([0,0,0,1])*VEL*TIME_GAP
        elif arg_action1 == 5:
            self.n_state[0:4] = arg_state[0:4] + np.array([0,0,0,-1])*VEL*TIME_GAP
        elif arg_action1 == 6:
            self.n_state[0:4] = arg_state[0:4] + np.array([0,0,-1,0])*VEL*TIME_GAP
        else:
            self.n_state[0:4] = arg_state[0:4] + np.array([0,0,1,0])*VEL*TIME_GAP      

       
        '''get the reward'''
        if np.linalg.norm((self.n_state[0:2]+self.n_state[2:4])/2-self.n_state[4:6])!=0:
            self.reward = (1/np.linalg.norm((self.n_state[0:2]+self.n_state[2:4])/2-self.n_state[4:6])-\
            1/np.linalg.norm((arg_state[0:2]+arg_state[2:4])/2-self.n_state[4:6]))*800
        if np.linalg.norm(self.n_state[0:2]-self.n_state[6:8])<1 or np.linalg.norm(self.n_state[2:4]-self.n_state[6:8])<1:
            self.reward = self.reward-2 # collision
        if np.linalg.norm(self.n_state[0:2]-self.n_state[8:10])<1 or np.linalg.norm(self.n_state[2:4]-self.n_state[8:10])<1:
            self.reward = self.reward-2 # collision
        if np.linalg.norm((self.n_state[0:2]+self.n_state[2:4])/2-self.n_state[4:6])<1 and np.linalg.norm(self.n_state[0:2]-self.n_state[2:4])<3: # approximately set condition
            self.reward = self.reward + 100 # achieve goal
            self._fail = True
        if np.linalg.norm(self.n_state[0:2]-self.n_state[2:4])>3:
            self.reward = self.reward-6*np.linalg.norm(self.n_state[0:2]-self.n_state[2:4]) # drop the object
            #self._fail = True            
        '''
        if any(x<0 for x in self.n_state):            
            self.reward = -50 # away from the map
            self._fail = True   
        if any(x>7 for x in self.n_state):            
            self.reward = -80 # away from the map
            self._fail = True 
        '''
        return self.n_state, self.reward, self._fail
    
#env = new_env() 
#state, g_pos, o_pos, o_size = env.create_env() # set the enviornment
DISCOUNT_RATE = 0.98
REPLAY_MEMORY = 10000
BATCH_SIZE = 50
MAX_EPI = 10000
MAX_STEP = 300
# minimum epsilon for epsilon greedy
MIN_E = 0.1
# epsilon will be `MIN_E` at `EPSILON_DECAYING_EPISODE`
EPSILON_DECAYING_STEP = MAX_STEP * 0.05
TARGET_UPDATE_FQ = 20

def train_minibatch(mainDQN, targetDQN, minibatch):
    state_array = np.array([x[0] for x in minibatch])
    action_array = np.array([x[1] for x in minibatch]) # [ x among 0~3] * BATCH_SIZE
    reward_array = np.array([x[2] for x in minibatch])
    n_state_array = np.array([x[3] for x in minibatch])
    _fail_array = np.array([x[4] for x in minibatch])    
    
    X_batch = state_array   
    Y_batch = mainDQN.predict(state_array) # 4 elements * BATCH_SIZE 
    
    # consideration for action constraint
    target_q = targetDQN.predict(n_state_array)
    j = 0
    for x in n_state_array:
        t_dqn = targetDQN.predict(x) #[[1 2 3 ...]]
        t_dqn = t_dqn.flatten() # [1 2 3 ...]
        if x[0]<TIME_GAP*VEL:
            t_dqn[2] = -float("inf") # put a large num on action 2(left)
        if x[1]<TIME_GAP*VEL:
            t_dqn[1] = -float("inf") # put a large num on action 1(down)
        if x[0] > MAP_SIZE - TIME_GAP*VEL:
            t_dqn[3] = -float("inf") # remove action 3(right)
        if x[1] > MAP_SIZE - TIME_GAP*VEL:
            t_dqn[0] = -float("inf") # remove action 0(up)  
        if x[2]<TIME_GAP*VEL:
            t_dqn[6] = -float("inf") # put a large num on action 6(left)
        if x[3]<TIME_GAP*VEL:
            t_dqn[5] = -float("inf") # put a large num on action 5(down)
        if x[2] > MAP_SIZE - TIME_GAP*VEL:
            t_dqn[7] = -float("inf") # remove action 7(right)
        if x[3] > MAP_SIZE - TIME_GAP*VEL:
            t_dqn[4] = -float("inf") # remove action 4(up)   
        target_q[j] = t_dqn
        j += 1
        
    Q_target = reward_array + DISCOUNT_RATE*np.max(target_q, axis=1)*~_fail_array # if fail, Q = reward
    
    Y_batch[np.arange(len(X_batch)), action_array] = Q_target
    
    # Train
    cost_batch, _ = mainDQN.update(X_batch, Y_batch)
    return cost_batch

def get_copy_var_ops(dest_scope_name = "target", src_scope_name = "main"):
    op_holder = []
    
    src_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=src_scope_name)
    dest_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=dest_scope_name)

    for src_var, dest_var in zip(src_vars, dest_vars):
        op_holder.append(dest_var.assign(src_var.value()))

    return op_holder


def main():
    replay_buffer = deque(maxlen=REPLAY_MEMORY) # detract element from both sides    
    total_reward_buffer = []
    step_buffer = []
    new_graph = tf.Graph()
    with tf.Session(graph=new_graph)) as sess:
        mainDQN = dqn_cooperation.DQN(sess, INPUT_SIZE, OUTPUT_SIZE)
        mainDQN.build_network(16,32,0.002)
        targetDQN = dqn_cooperation.DQN(sess, INPUT_SIZE, OUTPUT_SIZE)
        targetDQN.build_network(16,32,0.002)
        init = tf.global_variables_initializer()
        sess.run(init)
        
         #restore model
        '''
        new_saver = tf.train.import_meta_graph("./dqn_single_action.ckpt.meta")        
        new_saver.restore(sess,"./dqn_single_action.ckpt")
        '''
        # initial copy main q -> target q
        copy_ops = get_copy_var_ops(dest_scope_name = "target", src_scope_name = "main")
        sess.run(copy_ops)
        
        reward_accum_last100 = 0
        reward_sum = 0


        game = ENV(MAP_SIZE, [0,7], [7,0], [0,0,1,1], [5,5]) # __init__(self, map_size, obs_pos1, obs_pos2, robot_start_pos, goal_pos):
        game.render_env()
        
        for episode in range(MAX_EPI):
            
            _fail = False
            step_count = 0 # how many moves included in an episode
            env1 = new_env()
            state, _= env1.create_env() # get only state, return self.state, self.goal_pos, self.obstacle_pos1, self.obstacle_pos2, self.obstacle_size

            goal_ = True
             
            reward_sum = 0    
            
            while not _fail:
                e = annealing_epsilon(step_count, MIN_E, 1.0, EPSILON_DECAYING_STEP)
                # after sufficient learning, we present the game scene        
                if episode > MAX_EP:
                    game.update(state)
                    game.render_env()
                    
                step_count += 1
                # apply constraint about walls                   
                if np.random.rand()< e:
                    act_candi = range(ACTION_NUM)
                    if state[0]<TIME_GAP*VEL:
                        act_candi.remove(2) # remove action 2(left)
                    if state[1]<TIME_GAP*VEL:
                        act_candi.remove(1) # remove action 1(down)
                    if state[0] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi.remove(3) # remove action 3(right)000000
                    if state[1] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi.remove(0) # remove action 0(up)    
                    if state[2]<TIME_GAP*VEL:
                        act_candi.remove(6) # remove action 6(left)
                    if state[3]<TIME_GAP*VEL:
                        act_candi.remove(5) # remove action 5(down)
                    if state[2] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi.remove(7) # remove action 7(right)
                    if state[3] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi.remove(4) # remove action 4(up)    
                    act_candi1 = np.array(act_candi)
                    action_l = random.sample(act_candi1,1) # choose upL, down, left, right 
                    action = action_l[0]
                else:  
                    act_candi = mainDQN.predict(state)
                    act_candi = act_candi.flatten()
                    
                    if state[0]<TIME_GAP*VEL:
                        act_candi[2] = -float("inf") # put a large num on action 2(left)
                    if state[1]<TIME_GAP*VEL:
                        act_candi[1] = -float("inf") # put a large num on action 1(down)
                    if state[0] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi[3] = -float("inf") # remove action 3(right)
                    if state[1] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi[0] = -float("inf") # remove action 0(up)  
                    if state[2]<TIME_GAP*VEL:
                        act_candi[6] = -float("inf") # put a large num on action 6(left)
                    if state[3]<TIME_GAP*VEL:
                        act_candi[5] = -float("inf") # put a large num on action 5(down)
                    if state[2] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi[7] = -float("inf") # remove action 7(right)
                    if state[3] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi[4] = -float("inf") # remove action 4(up)    
                    action = np.argmax(act_candi)   
                    '''
                    dd_predict = mainDQN.predict(state).flatten()
                    aa = np.max(dd_predict)
                    max_indx, = np.where(dd_predict==aa)                    
                    action = random.sample(max_indx,1)[0]
                    '''
                    
                n_state, reward, _fail = env1.next_step(state, action)
                replay_buffer.append((state, action, reward, n_state, _fail))
                '''
                get the reward once every two steps
                
                if step_count%2 == 1:
                    state_mem = state
                    action_mem = action
                    n_state, reward, _fail = env1.next_step(state, action) # have to input the action 

                    if _fail == False:
                        reward = 0 # do not allocate
                    else:
                        replay_buffer.append((state, action, reward, n_state, _fail))
                if step_count%2 == 0:
                    n_state, reward, _fail = env1.next_step(state, action) # have to input the action 
                    replay_buffer.append((state_mem, action_mem, reward/2, state, _fail)) # each action has responsibility of reward equally
                    replay_buffer.append((state, action, reward/2, n_state, _fail)) 
                # if count >30, stop that episode and start new episode, counted every time one agent moves
                '''
                if step_count >MAX_STEP-1:
                    #reward = -30
                    _fail = True   
                    goal_ = False
                
                reward_sum += reward    # sum total reward and penalty about long time(-0.5)                                  
                state = n_state
             
                if len(replay_buffer)>BATCH_SIZE*4:
                    minibatch = random.sample(replay_buffer, BATCH_SIZE)                    
                    train_minibatch(mainDQN, targetDQN, minibatch)
                if step_count % TARGET_UPDATE_FQ == 0:
                    sess.run(copy_ops)
                    
            total_reward_buffer.append(reward_sum)
            step_buffer.append(step_count)
            if goal_ == True:
                print("[Episode {:>5}]  total reward: {:>5}  steps: {:>5}, success".format(episode, reward_sum, step_count))
            else:
                print("[Episode {:>5}]  total reward: {:>5}  steps: {:>5}, failure".format(episode, reward_sum, step_count))
    
        #print("Success ratio: {}".format(reward_accum_last100/100))
        fig1 =plt.figure()
        plt.plot(range(MAX_EPI), total_reward_buffer)
        plt.show()
        
        # save model        
        save_path = new_saver.save(sess, "./dqn_single_action.ckpt")   
        # save data (reward, step)
        f = open("reward_s.txt", 'w')
        for i in range(len(total_reward_buffer)):
            f.write("{:>5}  {:>5}\n".format(total_reward_buffer[i], step_buffer[i]))
        f.close
        
if __name__ == "__main__":
    main()    
    end = time.time()-start
    print(end)
# Out:
# /home/hotae319/anaconda2/envs/tensorflow/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <img src="data:image/png;base64,..." width="640">
# [Episode     0]  total reward: -292.780808811, success
# [Episode     1]  total reward: -1662.83510444, failure
# [Episode     2]  total reward: -542.835104445, success
# [Episode     3]  total reward: -1566.83510444, failure
# [Episode     4]  total reward: -1060.83510444, success
# [Episode     5]  total reward: -1026.78080881, failure
# [Episode     6]  total reward: -770.780808811, failure
# [Episode     7]  total reward: -880.835104445, success
# [Episode     8]  total reward: -900.780808811, failure
# [Episode     9]  total reward: -1014.78080881, failure
# [Episode    10]  total reward: -844.835104445, failure
# [Episode    11]  total reward: -1146.83510444, failure
# [Episode    12]  total reward: -1228.83510444, failure
# [Episode    13]  total reward: -1076.78080881, failure
# [Episode    14]  total reward: -638.780808811, failure
# [Episode    15]  total reward: -780.780808811, failure
# [Episode    16]  total reward: -534.835104445, success
# [Episode    17]  total reward: -626.835104445, success
# [Episode    18]  total reward: -736.835104445, failure
# [Episode    19]  total reward: -838.835104445, success
# [Episode    20]  total reward: -1054.83510444, failure
# [Episode    21]  total reward: -1430.83510444, failure
# [Episode    22]  total reward: -1074.78080881, failure
# [Episode    23]  total reward: -888.835104445, success
# [Episode    24]  total reward: -208.835104445, success
# [Episode    25]  total reward: -1194.83510444, failure
# [Episode    26]  total reward: -1006.78080881, failure
# [Episode    27]  total reward: -1274.78080881, failure
# [Episode    28]  total reward: -1208.78080881, failure
# [Episode    29]  total reward: -1494.78080881, failure
# [Episode    30]  total reward: -70.835104445, success
# [Episode    31]  total reward: -186.835104445, success
# [Episode    32]  total reward: -138.835104445, success
# [Episode    33]  total reward: -510.835104445, success
# [Episode    34]  total reward: -1428.83510444, failure
# [Episode    35]  total reward: -224.780808811, success
# [Episode    36]  total reward: -240.835104445, success
# [Episode    37]  total reward: -166.835104445, success
# [Episode    38]  total reward: -594.780808811, failure
# [Episode    39]  total reward: -490.835104445, success
# [Episode    40]  total reward: -576.835104445, success
# [Episode    41]  total reward: -538.835104445, success
# [Episode    42]  total reward: -406.835104445, success
# [Episode    43]  total reward: -110.780808811, success
# [Episode    44]  total reward: -190.835104445, success
# [Episode    45]  total reward: -1380.83510444, failure
# [Episode    46]  total reward: -334.835104445, success
# [Episode    47]  total reward: -1244.83510444, success
# [Episode    48]  total reward: -1176.83510444, success
# [Episode    49]  total reward: -208.835104445, success
# [Episode    50]  total reward: -346.835104445, success
# [Episode    51]  total reward: -46.835104445, success
# [Episode    52]  total reward: -82.835104445, success
# [Episode    53]  total reward: 75.2191911886, success
# [Episode    54]  total reward: -934.780808811, success
# [Episode    55]  total reward: -1006.83510444, success
# [Episode    56]  total reward: -762.780808811, success
# [Episode    57]  total reward: -124.835104445, success
# [Episode    58]  total reward: -88.835104445, success
# [Episode    59]  total reward: -84.835104445, success
# [Episode    60]  total reward: 11.164895555, success
# [Episode    61]  total reward: -190.835104445, success
# [Episode    62]  total reward: -1164.83510444, success
# [Episode    63]  total reward: -94.835104445, success
# [Episode    64]  total reward: -88.835104445, success
# [Episode    65]  total reward: -808.835104445, success
# [Episode    66]  total reward: -162.780808811, success
# [Episode    67]  total reward: 101.164895555, success
# [Episode    68]  total reward: -706.835104445, success
# [Episode    69]  total reward: -94.835104445, success
# [Episode    70]  total reward: -222.835104445, success
# [Episode    71]  total reward: -358.835104445, success
# [Episode    72]  total reward: -136.835104445, success
# [Episode    73]  total reward: -292.835104445, success
# [Episode    74]  total reward: -294.780808811, success
# [Episode    75]  total reward: -30.835104445, success
# [Episode    76]  total reward: -998.835104445, failure
# [Episode    77]  total reward: -130.835104445, success
# [Episode    78]  total reward: -118.835104445, success
# [Episode    79]  total reward: -676.835104445, success
# [Episode    80]  total reward: -352.835104445, success
# [Episode    81]  total reward: -1044.83510444, success
# [Episode    82]  total reward: -502.835104445, success
# [Episode    83]  total reward: -682.835104445, success
# [Episode    84]  total reward: -234.835104445, success
# [Episode    85]  total reward: -178.835104445, success
# [Episode    86]  total reward: -1046.78080881, success
# [Episode    87]  total reward: -322.835104445, success
# [Episode    88]  total reward: -112.835104445, success
# [Episode    89]  total reward: -124.835104445, success
# [Episode    90]  total reward: -118.835104445, success
# [Episode    91]  total reward: -354.835104445, success
# [Episode    92]  total reward: -400.835104445, success
# [Episode    93]  total reward: -96.7808088114, success
# [Episode    94]  total reward: -70.835104445, success
# [Episode    95]  total reward: -286.835104445, success
# [Episode    96]  total reward: -270.835104445, success
# [Episode    97]  total reward: -226.835104445, success
# [Episode    98]  total reward: -412.835104445, success
# [Episode    99]  total reward: -28.835104445, success
# [Episode   100]  total reward: -544.835104445, success
# [Episode   101]  total reward: -216.835104445, success
# [Episode   102]  total reward: -88.835104445, success
# [Episode   103]  total reward: -584.835104445, success
# [Episode   104]  total reward: -288.835104445, success
# [Episode   105]  total reward: -136.835104445, success
# [Episode   106]  total reward: -184.835104445, success
# [Episode   107]  total reward: -76.835104445, success
# [Episode   108]  total reward: -352.835104445, success
# [Episode   109]  total reward: 59.164895555, success
# [Episode   110]  total reward: -138.780808811, success
# [Episode   111]  total reward: -88.835104445, success
# [Episode   112]  total reward: -262.835104445, success
# [Episode   113]  total reward: -766.835104445, success
# [Episode   114]  total reward: 77.164895555, success
# [Episode   115]  total reward: -48.835104445, success
# [Episode   116]  total reward: -172.835104445, success
# [Episode   117]  total reward: -406.835104445, success
# [Episode   118]  total reward: -186.835104445, success
# [Episode   119]  total reward: -108.835104445, success
# [Episode   120]  total reward: -70.835104445, success
# [Episode   121]  total reward: -244.835104445, success
# [Episode   122]  total reward: -274.835104445, success
# [Episode   123]  total reward: -398.835104445, success
# [Episode   124]  total reward: -790.835104445, success
# [Episode   125]  total reward: -484.835104445, success
# [Episode   126]  total reward: -1216.83510444, failure
# [Episode   127]  total reward: -652.835104445, success
# [Episode   128]  total reward: -106.835104445, success
# [Episode   129]  total reward: -464.835104445, success
# [Episode   130]  total reward: -1374.78080881, failure
# [Episode   131]  total reward: -454.835104445, success
# [Episode   132]  total reward: -400.835104445, success
# [Episode   133]  total reward: -302.835104445, success
# [Episode   134]  total reward: -1134.83510444, success
# [Episode   135]  total reward: -686.835104445, success
# [Episode   136]  total reward: -192.835104445, success
# [Episode   137]  total reward: -142.835104445, success
# [Episode   138]  total reward: -592.835104445, success
# [Episode   139]  total reward: -412.835104445, success
# [Episode   140]  total reward: -714.835104445, success
# [Episode   141]  total reward: -214.835104445, success
# [Episode   142]  total reward: -1210.83510444, failure
# [Episode   143]  total reward: -82.835104445, success
# [Episode   144]  total reward: -838.835104445, success
# [Episode   145]  total reward: -382.835104445, success
# [Episode   146]  total reward: -1064.83510444, success
# [Episode   147]  total reward: -280.835104445, success
# [Episode   148]  total reward: -468.835104445, success
# [Episode   149]  total reward: -264.780808811, success
# [Episode   150]  total reward: -160.835104445, success
# [Episode   151]  total reward: -906.835104445, success
# [Episode   152]  total reward: -1294.83510444, success
# [Episode   153]  total reward: -214.835104445, success
# [Episode   154]  total reward: -442.835104445, success
# [Episode   155]  total reward: -88.835104445, success
# [Episode   156]  total reward: -42.835104445, success
# [Episode   157]  total reward: -478.835104445, success
# [Episode   158]  total reward: -178.835104445, success
# [Episode   159]  total reward: -154.835104445, success
# [Episode   160]  total reward: -322.835104445, success
# [Episode   161]  total reward: -70.835104445, success
# [Episode   162]  total reward: -172.835104445, success
# [Episode   163]  total reward: -46.835104445, success
# [Episode   164]  total reward: -190.835104445, success
# [Episode   165]  total reward: -694.835104445, success
# [Episode   166]  total reward: -40.835104445, success
# [Episode   167]  total reward: -312.780808811, success
# [Episode   168]  total reward: -106.835104445, success
# [Episode   169]  total reward: -118.835104445, success
# [Episode   170]  total reward: -88.835104445, success
# [Episode   171]  total reward: -154.835104445, success
# [Episode   172]  total reward: -82.835104445, success
# [Episode   173]  total reward: -602.835104445, success
# [Episode   174]  total reward: -82.835104445, success
# [Episode   175]  total reward: -388.835104445, success
# [Episode   176]  total reward: -136.835104445, success
# [Episode   177]  total reward: -100.835104445, success
# [Episode   178]  total reward: -148.835104445, success
# [Episode   179]  total reward: -154.835104445, success
# [Episode   180]  total reward: -394.835104445, success
# [Episode   181]  total reward: -82.835104445, success
# [Episode   182]  total reward: -40.835104445, success
# [Episode   183]  total reward: -102.780808811, success
# [Episode   184]  total reward: -252.835104445, success
# [Episode   185]  total reward: -46.835104445, success
# [Episode   186]  total reward: -276.835104445, success
# [Episode   187]  total reward: -4.83510444496, success
# [Episode   188]  total reward: -106.835104445, success
# [Episode   189]  total reward: -100.835104445, success
# [Episode   190]  total reward: -76.835104445, success
# [Episode   191]  total reward: -178.835104445, success
# [Episode   192]  total reward: -76.835104445, success
# [Episode   193]  total reward: -106.835104445, success
# [Episode   194]  total reward: -70.835104445, success
# [Episode   195]  total reward: -190.835104445, success
# [Episode   196]  total reward: -136.835104445, success
# [Episode   197]  total reward: -82.835104445, success
# [Episode   198]  total reward: -82.835104445, success
# [Episode   199]  total reward: -22.835104445, success
# [Episode   200]  total reward: 107.164895555, success
# [Episode   201]  total reward: -310.835104445, success
# [Episode   202]  total reward: 1.16489555504, success
# [Episode   203]  total reward: -10.835104445, success
# [Episode   204]  total reward: -166.835104445, success
# [Episode   205]  total reward: -100.835104445, success
# [Episode   206]  total reward: -40.835104445, success
# [Episode   207]  total reward: -1390.83510444, success
# [Episode   208]  total reward: -16.835104445, success
# [Episode   209]  total reward: -124.835104445, success
# [Episode   210]  total reward: -102.780808811, success
# [Episode   211]  total reward: -496.835104445, success
# [Episode   212]  total reward: -298.835104445, success
# [Episode   213]  total reward: -460.835104445, success
# [Episode   214]  total reward: -22.835104445, success
# [Episode   215]  total reward: -250.835104445, success
# [Episode   216]  total reward: -58.835104445, success
# [Episode   217]  total reward: -1212.78080881, success
# [Episode   218]  total reward: -130.835104445, success
# [Episode   219]  total reward: -76.835104445, success
# [Episode   220]  total reward: -82.835104445, success
# [Episode   221]  total reward: -88.835104445, success
# [Episode   222]  total reward: -76.835104445, success
# [Episode   223]  total reward: -544.835104445, success
# [Episode   224]  total reward: -96.7808088114, success
# [Episode   225]  total reward: 89.164895555, success
# [Episode   226]  total reward: -76.835104445, success
# [Episode   227]  total reward: 107.164895555, success
# [Episode   228]  total reward: -88.835104445, success
# [Episode   229]  total reward: -118.835104445, success
# [Episode   230]  total reward: -64.835104445, success
# [Episode   231]  total reward: -94.835104445, success
# [Episode   232]  total reward: -1246.83510444, success
# [Episode   233]  total reward: -1576.83510444, success
# [Episode   234]  total reward: -88.835104445, success
# [Episode   235]  total reward: -82.835104445, success
# [Episode   236]  total reward: -112.835104445, success
# [Episode   237]  total reward: -1534.83510444, success
# [Episode   238]  total reward: -118.835104445, success
# [Episode   239]  total reward: -370.835104445, success
# [Episode   240]  total reward: -388.835104445, success
# [Episode   241]  total reward: -46.835104445, success
# [Episode   242]  total reward: -46.835104445, success
# [Episode   243]  total reward: -82.835104445, success
# [Episode   244]  total reward: -562.835104445, success
# [Episode   245]  total reward: -82.835104445, success
# [Episode   246]  total reward: -70.835104445, success
# [Episode   247]  total reward: -112.835104445, success
# [Episode   248]  total reward: -112.835104445, success
# [Episode   249]  total reward: -70.835104445, success
# [Episode   250]  total reward: -58.835104445, success
# [Episode   251]  total reward: 17.164895555, success
# [Episode   252]  total reward: -1192.83510444, success
# [Episode   253]  total reward: -592.835104445, success
# [Episode   254]  total reward: -1702.83510444, failure
# [Episode   255]  total reward: -40.835104445, success
# [Episode   256]  total reward: 77.164895555, success
# [Episode   257]  total reward: -178.835104445, success
# [Episode   258]  total reward: -70.835104445, success
# [Episode   259]  total reward: -70.835104445, success
# [Episode   260]  total reward: 107.164895555, success
# [Episode   261]  total reward: -46.835104445, success
# [Episode   262]  total reward: -94.835104445, success
# [Episode   263]  total reward: -352.835104445, success
# [Episode   264]  total reward: -202.835104445, success
# [Episode   265]  total reward: -64.835104445, success
# [Episode   266]  total reward: -106.835104445, success
# [Episode   267]  total reward: -34.835104445, success
# [Episode   268]  total reward: -484.835104445, success
# [Episode   269]  total reward: -64.835104445, success
# [Episode   270]  total reward: -76.835104445, success
# [Episode   271]  total reward: -250.835104445, success
# [Episode   272]  total reward: -82.835104445, success
# [Episode   273]  total reward: -88.835104445, success
# [Episode   274]  total reward: -226.835104445, success
# [Episode   275]  total reward: -58.835104445, success
# [Episode   276]  total reward: -52.835104445, success
# [Episode   277]  total reward: -46.835104445, success
# [Episode   278]  total reward: -88.835104445, success
# [Episode   279]  total reward: 41.164895555, success
# [Episode   280]  total reward: -70.835104445, success
# [Episode   281]  total reward: -82.835104445, success
# [Episode   282]  total reward: -88.835104445, success
# [Episode   283]  total reward: -58.835104445, success
# [Episode   284]  total reward: -82.835104445, success
# [Episode   285]  total reward: 101.164895555, success
# [Episode   286]  total reward: -106.835104445, success
# [Episode   287]  total reward: -88.835104445, success
# [Episode   288]  total reward: -304.835104445, success
# [Episode   289]  total reward: -120.780808811, success
# [Episode   290]  total reward: 17.164895555, success
# [Episode   291]  total reward: -70.835104445, success
# [Episode   292]  total reward: -184.835104445, success
# [Episode   293]  total reward: -88.835104445, success
# [Episode   294]  total reward: -76.835104445, success
# [Episode   295]  total reward: -88.835104445, success
# [Episode   296]  total reward: -94.835104445, success
# [Episode   297]  total reward: -82.835104445, success
# [Episode   298]  total reward: -108.835104445, success
# [Episode   299]  total reward: -94.835104445, success
# [Episode   300]  total reward: -82.835104445, success
# [Episode   301]  total reward: -82.835104445, success
# [Episode   302]  total reward: -160.835104445, success
# [Episode   303]  total reward: -594.835104445, success
# [Episode   304]  total reward: -76.835104445, success
# [Episode   305]  total reward: -94.835104445, success
# [Episode   306]  total reward: -94.835104445, success
# [Episode   307]  total reward: -118.835104445, success
# [Episode   308]  total reward: -88.835104445, success
# [Episode   309]  total reward: -88.835104445, success
# [Episode   310]  total reward: -82.835104445, success
# [Episode   311]  total reward: -112.835104445, success
# [Episode   312]  total reward: -88.835104445, success
# [Episode   313]  total reward: -94.835104445, success
# [Episode   314]  total reward: -82.835104445, success
# [Episode   315]  total reward: -100.835104445, success
# [Episode   316]  total reward: -94.835104445, success
# [Episode   317]  total reward: 17.164895555, success
# [Episode   318]  total reward: -94.835104445, success
# [Episode   319]  total reward: -88.835104445, success
# [Episode   320]  total reward: -70.835104445, success
# [Episode   321]  total reward: -88.835104445, success
# [Episode   322]  total reward: -88.835104445, success
# [Episode   323]  total reward: -94.835104445, success
# [Episode   324]  total reward: -88.835104445, success
# [Episode   325]  total reward: -88.835104445, success
# [Episode   326]  total reward: -88.835104445, success
# [Episode   327]  total reward: -136.835104445, success
# [Episode   328]  total reward: -94.835104445, success
# [Episode   329]  total reward: -94.835104445, success
# [Episode   330]  total reward: -100.835104445, success
# [Episode   331]  total reward: -88.835104445, success
# [Episode   332]  total reward: -82.835104445, success
# [Episode   333]  total reward: -100.835104445, success
# [Episode   334]  total reward: -94.835104445, success
# [Episode   335]  total reward: -100.835104445, success
# [Episode   336]  total reward: -82.835104445, success
# [Episode   337]  total reward: -118.835104445, success
# [Episode   338]  total reward: -88.835104445, success
# [Episode   339]  total reward: -106.835104445, success
# [Episode   340]  total reward: -94.835104445, success
# [Episode   341]  total reward: -94.835104445, success
# [Episode   342]  total reward: -88.835104445, success
# [Episode   343]  total reward: 11.164895555, success
# [Episode   344]  total reward: -94.835104445, success
# [Episode   345]  total reward: -168.835104445, success
# [Episode   346]  total reward: -82.835104445, success
# [Episode   347]  total reward: -88.835104445, success
# [Episode   348]  total reward: -82.835104445, success
# [Episode   349]  total reward: -82.835104445, success
# [Episode   350]  total reward: -82.835104445, success
# [Episode   351]  total reward: -118.835104445, success
# [Episode   352]  total reward: -94.835104445, success
# [Episode   353]  total reward: -88.835104445, success
# [Episode   354]  total reward: -94.835104445, success
# [Episode   355]  total reward: -94.835104445, success
# [Episode   356]  total reward: -76.835104445, success
# [Episode   357]  total reward: -100.835104445, success
# [Episode   358]  total reward: -100.835104445, success
# [Episode   359]  total reward: -94.835104445, success
# [Episode   360]  total reward: -82.835104445, success
# [Episode   361]  total reward: -88.835104445, success
# [Episode   362]  total reward: -88.835104445, success
# [Episode   363]  total reward: -88.835104445, success
# [Episode   364]  total reward: -88.835104445, success
# [Episode   365]  total reward: -88.835104445, success
# [Episode   366]  total reward: -88.835104445, success
# [Episode   367]  total reward: -88.835104445, success
# [Episode   368]  total reward: -88.835104445, success
# [Episode   369]  total reward: -82.835104445, success
# [Episode   370]  total reward: -94.835104445, success
# [Episode   371]  total reward: -88.835104445, success
# [Episode   372]  total reward: -70.835104445, success
# [Episode   373]  total reward: -82.835104445, success
# [Episode   374]  total reward: -112.835104445, success
# [Episode   375]  total reward: -100.835104445, success
# [Episode   376]  total reward: -100.835104445, success
# [Episode   377]  total reward: -94.835104445, success
# [Episode   378]  total reward: -94.835104445, success
# [Episode   379]  total reward: -106.835104445, success
# [Episode   380]  total reward: -70.835104445, success
# [Episode   381]  total reward: -94.835104445, success
# [Episode   382]  total reward: -88.835104445, success
# [Episode   383]  total reward: -88.835104445, success
# [Episode   384]  total reward: -82.835104445, success
# [Episode   385]  total reward: -82.835104445, success
# [Episode   386]  total reward: -94.835104445, success
# [Episode   387]  total reward: -100.835104445, success
# [Episode   388]  total reward: -106.835104445, success
# [Episode   389]  total reward: -82.835104445, success
# [Episode   390]  total reward: -82.835104445, success
# [Episode   391]  total reward: -88.835104445, success
# [Episode   392]  total reward: -94.835104445, success
# [Episode   393]  total reward: -82.835104445, success
# [Episode   394]  total reward: -88.835104445, success
# [Episode   395]  total reward: -76.835104445, success
# [Episode   396]  total reward: -106.835104445, success
# [Episode   397]  total reward: -82.835104445, success
# [Episode   398]  total reward: -88.835104445, success
# [Episode   399]  total reward: -88.835104445, success
# [Episode   400]  total reward: -88.835104445, success
# [Episode   401]  total reward: -94.835104445, success
# [Episode   402]  total reward: -88.835104445, success
# [Episode   403]  total reward: -160.835104445, success
# [Episode   404]  total reward: -94.835104445, success
# [Episode   405]  total reward: -94.835104445, success
# [Episode   406]  total reward: -94.835104445, success
# [Episode   407]  total reward: -94.835104445, success
# [Episode   408]  total reward: -88.835104445, success
# [Episode   409]  total reward: -94.835104445, success
# [Episode   410]  total reward: -82.835104445, success
# [Episode   411]  total reward: -82.835104445, success
# [Episode   412]  total reward: -88.835104445, success
# [Episode   413]  total reward: -88.835104445, success
# [Episode   414]  total reward: 41.164895555, success
# [Episode   415]  total reward: -88.835104445, success
# [Episode   416]  total reward: -82.835104445, success
# [Episode   417]  total reward: -100.835104445, success
# [Episode   418]  total reward: -70.835104445, success
# [Episode   419]  total reward: -94.835104445, success
# [Episode   420]  total reward: -100.835104445, success
# [Episode   421]  total reward: -82.835104445, success
# [Episode   422]  total reward: -112.835104445, success
# [Episode   423]  total reward: -94.835104445, success
# [Episode   424]  total reward: -88.835104445, success
# [Episode   425]  total reward: -88.835104445, success
# [Episode   426]  total reward: -88.835104445, success
# [Episode   427]  total reward: -88.835104445, success
# [Episode   428]  total reward: -88.835104445, success
# [Episode   429]  total reward: -88.835104445, success
# [Episode   430]  total reward: -82.835104445, success
# [Episode   431]  total reward: -106.835104445, success
# [Episode   432]  total reward: -82.835104445, success
# [Episode   433]  total reward: -88.835104445, success
# [Episode   434]  total reward: -94.835104445, success
# [Episode   435]  total reward: -88.835104445, success
# [Episode   436]  total reward: -88.835104445, success
# [Episode   437]  total reward: -106.835104445, success
# [Episode   438]  total reward: -94.835104445, success
# [Episode   439]  total reward: -88.835104445, success
# [Episode   440]  total reward: -102.780808811, success
# [Episode   441]  total reward: -94.835104445, success
# [Episode   442]  total reward: -88.835104445, success
# [Episode   443]  total reward: -100.835104445, success
# [Episode   444]  total reward: -88.835104445, success
# [Episode   445]  total reward: -106.835104445, success
# [Episode   446]  total reward: -82.835104445, success
# [Episode   447]  total reward: -94.835104445, success
# [Episode   448]  total reward: -82.835104445, success
# [Episode   449]  total reward: -100.835104445, success
# [Episode   450]  total reward: -88.835104445, success
# [Episode   451]  total reward: -106.835104445, success
# [Episode   452]  total reward: -76.835104445, success
# [Episode   453]  total reward: -88.835104445, success
# [Episode   454]  total reward: -82.835104445, success
# [Episode   455]  total reward: -88.835104445, success
# [Episode   456]  total reward: -88.835104445, success
# [Episode   457]  total reward: -88.835104445, success
# [Episode   458]  total reward: -100.835104445, success
# [Episode   459]  total reward: -76.835104445, success
# [Episode   460]  total reward: -94.835104445, success
# [Episode   461]  total reward: -88.835104445, success
# [Episode   462]  total reward: -100.835104445, success
# [Episode   463]  total reward: -178.835104445, success
# [Episode   464]  total reward: -88.835104445, success
# [Episode   465]  total reward: -94.835104445, success
# [Episode   466]  total reward: -114.780808811, success
# [Episode   467]  total reward: -100.835104445, success
# [Episode   468]  total reward: -88.835104445, success
# [Episode   469]  total reward: -94.835104445, success
# [Episode   470]  total reward: -88.835104445, success
# [Episode   471]  total reward: -100.835104445, success
# [Episode   472]  total reward: 47.164895555, success
# [Episode   473]  total reward: 65.164895555, success
# [Episode   474]  total reward: -360.835104445, success
# [Episode   475]  total reward: 83.164895555, success
# [Episode   476]  total reward: -112.835104445, success
# [Episode   477]  total reward: 17.164895555, success
# [Episode   478]  total reward: -112.835104445, success
# [Episode   479]  total reward: -82.835104445, success
# [Episode   480]  total reward: -88.835104445, success
# [Episode   481]  total reward: 23.164895555, success
# [Episode   482]  total reward: -64.835104445, success
# [Episode   483]  total reward: -64.835104445, success
# [Episode   484]  total reward: -112.835104445, success
# [Episode   485]  total reward: -94.835104445, success
# [Episode   486]  total reward: -88.835104445, success
# [Episode   487]  total reward: -100.835104445, success
# [Episode   488]  total reward: -88.835104445, success
# [Episode   489]  total reward: -358.835104445, success
# [Episode   490]  total reward: -88.835104445, success
# [Episode   491]  total reward: -114.780808811, success
# [Episode   492]  total reward: -82.835104445, success
# [Episode   493]  total reward: -88.835104445, success
# [Episode   494]  total reward: -94.835104445, success
# [Episode   495]  total reward: -100.835104445, success
# [Episode   496]  total reward: -82.835104445, success
# [Episode   497]  total reward: -82.835104445, success
# [Episode   498]  total reward: -82.835104445, success
# [Episode   499]  total reward: -82.835104445, success
# [Episode   500]  total reward: -76.835104445, success
# [Episode   501]  total reward: 41.164895555, success
# [Episode   502]  total reward: -88.835104445, success
# [Episode   503]  total reward: -88.835104445, success
# [Episode   504]  total reward: -94.835104445, success
# [Episode   505]  total reward: -510.835104445, failure
# [Episode   506]  total reward: -88.835104445, success
# [Episode   507]  total reward: -70.835104445, success
# [Episode   508]  total reward: 101.164895555, success
# [Episode   509]  total reward: -88.835104445, success
# [Episode   510]  total reward: -106.835104445, success
# [Episode   511]  total reward: -100.835104445, success
# [Episode   512]  total reward: -100.835104445, success
# [Episode   513]  total reward: -100.835104445, success
# [Episode   514]  total reward: -82.835104445, success
# [Episode   515]  total reward: -82.835104445, success
# [Episode   516]  total reward: -70.835104445, success
# [Episode   517]  total reward: -88.835104445, success
# [Episode   518]  total reward: -100.835104445, success
# [Episode   519]  total reward: -88.835104445, success
# [Episode   520]  total reward: 41.164895555, success
# [Episode   521]  total reward: -88.835104445, success
# [Episode   522]  total reward: -88.835104445, success
# [Episode   523]  total reward: -82.835104445, success
# [Episode   524]  total reward: -100.835104445, success
# [Episode   525]  total reward: -88.835104445, success
# [Episode   526]  total reward: 101.164895555, success
# [Episode   527]  total reward: -118.835104445, success
# [Episode   528]  total reward: -118.835104445, success
# [Episode   529]  total reward: -100.835104445, success
# [Episode   530]  total reward: -100.835104445, success
# [Episode   531]  total reward: -70.835104445, success
# [Episode   532]  total reward: -64.835104445, success
# [Episode   533]  total reward: 77.164895555, success
# [Episode   534]  total reward: 83.164895555, success
# [Episode   535]  total reward: -82.835104445, success
# [Episode   536]  total reward: -70.835104445, success
# [Episode   537]  total reward: -118.835104445, success
# [Episode   538]  total reward: -88.835104445, success
# [Episode   539]  total reward: -82.835104445, success
# [Episode   540]  total reward: -88.835104445, success
# [Episode   541]  total reward: -82.835104445, success
# [Episode   542]  total reward: -82.835104445, success
# [Episode   543]  total reward: -82.835104445, success
# [Episode   544]  total reward: -82.835104445, success
# [Episode   545]  total reward: -88.835104445, success
# [Episode   546]  total reward: -88.835104445, success
# [Episode   547]  total reward: -166.835104445, success
# [Episode   548]  total reward: -256.835104445, success
# [Episode   549]  total reward: -88.835104445, success
# [Episode   550]  total reward: -94.835104445, success
# [Episode   551]  total reward: -136.835104445, success
# [Episode   552]  total reward: -82.835104445, success
# [Episode   553]  total reward: -82.835104445, success
# [Episode   554]  total reward: -82.835104445, success
# [Episode   555]  total reward: -100.835104445, success
# [Episode   556]  total reward: -100.835104445, success
# [Episode   557]  total reward: -88.835104445, success
# [Episode   558]  total reward: -88.835104445, success
# [Episode   559]  total reward: 47.164895555, success
# [Episode   560]  total reward: -88.835104445, success
# [Episode   561]  total reward: -88.835104445, success
# [Episode   562]  total reward: -88.835104445, success
# [Episode   563]  total reward: -94.835104445, success
# [Episode   564]  total reward: -112.835104445, success
# [Episode   565]  total reward: -94.835104445, success
# [Episode   566]  total reward: -88.835104445, success
# [Episode   567]  total reward: -88.835104445, success
# [Episode   568]  total reward: -250.835104445, success
# [Episode   569]  total reward: -94.835104445, success
# [Episode   570]  total reward: -142.835104445, success
# [Episode   571]  total reward: 47.164895555, success
# [Episode   572]  total reward: -100.835104445, success
# [Episode   573]  total reward: -94.835104445, success
# [Episode   574]  total reward: -88.835104445, success
# [Episode   575]  total reward: -94.835104445, success
# [Episode   576]  total reward: -82.835104445, success
# [Episode   577]  total reward: -82.835104445, success
# [Episode   578]  total reward: -88.835104445, success
# [Episode   579]  total reward: -100.835104445, success
# [Episode   580]  total reward: -88.835104445, success
# [Episode   581]  total reward: -370.835104445, success
# [Episode   582]  total reward: -88.835104445, success
# [Episode   583]  total reward: -88.835104445, success
# [Episode   584]  total reward: -88.835104445, success
# [Episode   585]  total reward: -76.835104445, success
# [Episode   586]  total reward: -100.835104445, success
# [Episode   587]  total reward: -100.835104445, success
# [Episode   588]  total reward: -82.835104445, success
# [Episode   589]  total reward: -106.835104445, success
# [Episode   590]  total reward: -82.835104445, success
# [Episode   591]  total reward: -106.835104445, success
# [Episode   592]  total reward: -82.835104445, success
# [Episode   593]  total reward: -82.835104445, success
# [Episode   594]  total reward: -88.835104445, success
# [Episode   595]  total reward: -88.835104445, success
# [Episode   596]  total reward: -88.835104445, success
# [Episode   597]  total reward: -106.835104445, success
# [Episode   598]  total reward: -94.835104445, success
# [Episode   599]  total reward: -142.835104445, success
# [Episode   600]  total reward: -88.835104445, success
# [Episode   601]  total reward: -88.835104445, success
# [Episode   602]  total reward: -94.835104445, success
# [Episode   603]  total reward: -94.835104445, success
# [Episode   604]  total reward: -96.7808088114, success
# [Episode   605]  total reward: -106.835104445, success
# [Episode   606]  total reward: -82.835104445, success
# [Episode   607]  total reward: -94.835104445, success
# [Episode   608]  total reward: -82.835104445, success
# [Episode   609]  total reward: -82.835104445, success
# [Episode   610]  total reward: -82.835104445, success
# [Episode   611]  total reward: -82.835104445, success
# [Episode   612]  total reward: -106.835104445, success
# [Episode   613]  total reward: -88.835104445, success
# [Episode   614]  total reward: -88.835104445, success
# [Episode   615]  total reward: -76.835104445, success
# [Episode   616]  total reward: -94.835104445, success
# [Episode   617]  total reward: -82.835104445, success
# [Episode   618]  total reward: -88.835104445, success
# [Episode   619]  total reward: -88.835104445, success
# [Episode   620]  total reward: -88.835104445, success
# [Episode   621]  total reward: -100.835104445, success
# [Episode   622]  total reward: -100.835104445, success
# [Episode   623]  total reward: -88.835104445, success
# [Episode   624]  total reward: -100.835104445, success
# [Episode   625]  total reward: -94.835104445, success
# [Episode   626]  total reward: -82.835104445, success
# [Episode   627]  total reward: -100.835104445, success
# [Episode   628]  total reward: -94.835104445, success
# [Episode   629]  total reward: -328.835104445, success
# [Episode   630]  total reward: -148.835104445, success
# [Episode   631]  total reward: -82.835104445, success
# [Episode   632]  total reward: -94.835104445, success
# [Episode   633]  total reward: -82.835104445, success
# [Episode   634]  total reward: -94.835104445, success
# [Episode   635]  total reward: -82.835104445, success
# [Episode   636]  total reward: -88.835104445, success
# [Episode   637]  total reward: -70.835104445, success
# [Episode   638]  total reward: -82.835104445, success
# [Episode   639]  total reward: -94.835104445, success
# [Episode   640]  total reward: -76.835104445, success
# [Episode   641]  total reward: -70.835104445, success
# [Episode   642]  total reward: -94.835104445, success
# [Episode   643]  total reward: -214.835104445, failure
# [Episode   644]  total reward: -94.835104445, success
# [Episode   645]  total reward: -172.835104445, success
# [Episode   646]  total reward: -124.835104445, success
# [Episode   647]  total reward: -94.835104445, success
# [Episode   648]  total reward: -82.835104445, success
# [Episode   649]  total reward: -94.835104445, success
# [Episode   650]  total reward: -76.835104445, success
# [Episode   651]  total reward: -4.83510444496, failure
# [Episode   652]  total reward: -70.835104445, success
# [Episode   653]  total reward: -84.7808088114, success
# [Episode   654]  total reward: -64.835104445, failure
# [Episode   655]  total reward: -358.835104445, success
# [Episode   656]  total reward: -144.780808811, success
# [Episode   657]  total reward: -562.835104445, success
# [Episode   658]  total reward: -124.835104445, success
# [Episode   659]  total reward: -268.835104445, success
# [Episode   660]  total reward: -82.835104445, success
# [Episode   661]  total reward: -82.835104445, success
# [Episode   662]  total reward: -34.835104445, success
# [Episode   663]  total reward: -868.835104445, success
# [Episode   664]  total reward: -82.835104445, success
# [Episode   665]  total reward: -94.835104445, success
# [Episode   666]  total reward: -682.835104445, success
# [Episode   667]  total reward: -94.835104445, success
# [Episode   668]  total reward: -106.835104445, success
# [Episode   669]  total reward: -1144.83510444, failure
# [Episode   670]  total reward: -772.835104445, failure
# [Episode   671]  total reward: -40.835104445, failure
# [Episode   672]  total reward: -10.835104445, failure
# [Episode   673]  total reward: -382.835104445, success
# [Episode   674]  total reward: 89.164895555, success
# [Episode   675]  total reward: -22.835104445, success
# [Episode   676]  total reward: -82.835104445, success
# [Episode   677]  total reward: -58.835104445, success
# [Episode   678]  total reward: -190.835104445, success
# [Episode   679]  total reward: -760.835104445, success
# [Episode   680]  total reward: -34.835104445, success
# [Episode   681]  total reward: -10.835104445, success
# [Episode   682]  total reward: -82.835104445, success
# [Episode   683]  total reward: -334.835104445, success
# [Episode   684]  total reward: -142.835104445, success
# [Episode   685]  total reward: -372.835104445, success
# [Episode   686]  total reward: -132.780808811, success
# [Episode   687]  total reward: -82.835104445, success
# [Episode   688]  total reward: -136.835104445, failure
# [Episode   689]  total reward: -646.835104445, success
# [Episode   690]  total reward: -334.835104445, failure
# [Episode   691]  total reward: -40.835104445, success
# [Episode   692]  total reward: 53.164895555, success
# [Episode   693]  total reward: -40.835104445, success
# [Episode   694]  total reward: -28.835104445, failure
# [Episode   695]  total reward: -142.835104445, success
# [Episode   696]  total reward: -166.835104445, failure
# [Episode   697]  total reward: -168.835104445, success
# [Episode   698]  total reward: -424.835104445, success
# [Episode   699]  total reward: -1108.83510444, failure
# [Episode   700]  total reward: -678.780808811, failure
# [Episode   701]  total reward: -1726.83510444, failure
# [Episode   702]  total reward: -1648.83510444, failure
# [Episode   703]  total reward: -1072.83510444, success
# [Episode   704]  total reward: -64.835104445, success
# [Episode   705]  total reward: -448.835104445, success
# [Episode   706]  total reward: -436.835104445, success
# [Episode   707]  total reward: -52.835104445, success
# [Episode   708]  total reward: -268.835104445, success
# [Episode   709]  total reward: -340.835104445, success
# [Episode   710]  total reward: 89.164895555, success
# [Episode   711]  total reward: -244.835104445, success
# [Episode   712]  total reward: -250.835104445, success
# [Episode   713]  total reward: -22.835104445, success
# [Episode   714]  total reward: -22.835104445, success
# [Episode   715]  total reward: -22.835104445, success
# [Episode   716]  total reward: -70.835104445, success
# [Episode   717]  total reward: -70.835104445, success
# [Episode   718]  total reward: -22.835104445, success
# [Episode   719]  total reward: -226.835104445, success
# [Episode   720]  total reward: -190.835104445, success
# [Episode   721]  total reward: -88.835104445, success
# [Episode   722]  total reward: -52.835104445, success
# [Episode   723]  total reward: -76.835104445, failure
# [Episode   724]  total reward: -622.835104445, failure
# [Episode   725]  total reward: -142.835104445, success
# [Episode   726]  total reward: -144.835104445, success
# [Episode   727]  total reward: -238.835104445, success
# [Episode   728]  total reward: 11.164895555, success
# [Episode   729]  total reward: -28.835104445, success
# [Episode   730]  total reward: -274.835104445, success
# [Episode   731]  total reward: -58.835104445, success
# [Episode   732]  total reward: -114.835104445, success
# [Episode   733]  total reward: -124.835104445, success
# [Episode   734]  total reward: -34.835104445, success
# [Episode   735]  total reward: -28.835104445, success
# [Episode   736]  total reward: -136.835104445, success
# [Episode   737]  total reward: -262.835104445, success
# [Episode   738]  total reward: -96.7808088114, success
# [Episode   739]  total reward: -184.835104445, success
# [Episode   740]  total reward: -802.835104445, failure
# [Episode   741]  total reward: -598.835104445, failure
# [Episode   742]  total reward: -462.835104445, failure
# [Episode   743]  total reward: -736.835104445, success
# [Episode   744]  total reward: -846.835104445, success
# [Episode   745]  total reward: -562.835104445, success
# [Episode   746]  total reward: -486.835104445, failure
# [Episode   747]  total reward: -1786.83510444, failure
# [Episode   748]  total reward: -792.835104445, success
# [Episode   749]  total reward: -1450.83510444, failure
# [Episode   750]  total reward: -1150.83510444, failure
# [Episode   751]  total reward: -796.835104445, success
# [Episode   752]  total reward: -70.835104445, success
# [Episode   753]  total reward: -114.835104445, success
# [Episode   754]  total reward: -796.835104445, failure
# [Episode   755]  total reward: -324.835104445, success
# [Episode   756]  total reward: -402.835104445, success
# [Episode   757]  total reward: -412.835104445, success
# [Episode   758]  total reward: -304.835104445, success
# [Episode   759]  total reward: -492.835104445, success
# [Episode   760]  total reward: -102.835104445, success
# [Episode   761]  total reward: -120.835104445, success
# [Episode   762]  total reward: -418.835104445, success
# [Episode   763]  total reward: -1252.83510444, failure
# [Episode   764]  total reward: 101.164895555, success
# [Episode   765]  total reward: -646.835104445, failure
# [Episode   766]  total reward: -1312.83510444, failure
# [Episode   767]  total reward: -934.835104445, failure
# [Episode   768]  total reward: -1038.83510444, failure
# [Episode   769]  total reward: -394.835104445, success
# [Episode   770]  total reward: -1164.83510444, failure
# [Episode   771]  total reward: -738.780808811, success
# [Episode   772]  total reward: -132.780808811, success
# [Episode   773]  total reward: -460.780808811, success
# [Episode   774]  total reward: -100.835104445, success
# [Episode   775]  total reward: -70.835104445, success
# [Episode   776]  total reward: -424.835104445, success
# [Episode   777]  total reward: -64.835104445, success
# [Episode   778]  total reward: -22.835104445, success
# [Episode   779]  total reward: -94.835104445, success
# [Episode   780]  total reward: -556.835104445, failure
# [Episode   781]  total reward: -20.835104445, success
# [Episode   782]  total reward: -628.835104445, success
# [Episode   783]  total reward: -70.835104445, success
# [Episode   784]  total reward: -226.835104445, success
# [Episode   785]  total reward: -310.835104445, success
# [Episode   786]  total reward: -82.835104445, success
# [Episode   787]  total reward: -72.7808088114, success
# [Episode   788]  total reward: -94.835104445, success
# [Episode   789]  total reward: -64.835104445, success
# [Episode   790]  total reward: -388.835104445, success
# [Episode   791]  total reward: -52.835104445, success
# [Episode   792]  total reward: -16.835104445, success
# [Episode   793]  total reward: -52.835104445, success
# [Episode   794]  total reward: -664.835104445, success
# [Episode   795]  total reward: -532.835104445, success
# [Episode   796]  total reward: -1438.83510444, failure
# [Episode   797]  total reward: -406.835104445, success
# [Episode   798]  total reward: -58.835104445, success
# [Episode   799]  total reward: -76.835104445, success
# [Episode   800]  total reward: -94.835104445, success
# [Episode   801]  total reward: -250.835104445, success
# [Episode   802]  total reward: -88.835104445, success
# [Episode   803]  total reward: -136.835104445, success
# [Episode   804]  total reward: -88.835104445, success
# [Episode   805]  total reward: -82.835104445, success
# [Episode   806]  total reward: -76.835104445, success
# [Episode   807]  total reward: -76.835104445, success
# [Episode   808]  total reward: -76.835104445, success
# [Episode   809]  total reward: -76.835104445, success
# [Episode   810]  total reward: -64.835104445, success
# [Episode   811]  total reward: -70.835104445, success
# [Episode   812]  total reward: -10.835104445, success
# [Episode   813]  total reward: -64.835104445, success
# [Episode   814]  total reward: -70.835104445, success
# [Episode   815]  total reward: -40.835104445, success
# [Episode   816]  total reward: -184.835104445, success
# [Episode   817]  total reward: -76.835104445, success
# [Episode   818]  total reward: -84.835104445, success
# [Episode   819]  total reward: -96.835104445, success
# [Episode   820]  total reward: -70.835104445, success
# [Episode   821]  total reward: -292.835104445, success
# [Episode   822]  total reward: -130.835104445, success
# [Episode   823]  total reward: -136.835104445, success
# [Episode   824]  total reward: -882.835104445, failure
# [Episode   825]  total reward: -1270.83510444, failure
# [Episode   826]  total reward: -568.835104445, success
# [Episode   827]  total reward: -346.835104445, success
# [Episode   828]  total reward: -328.835104445, success
# [Episode   829]  total reward: -112.835104445, success
# [Episode   830]  total reward: -100.835104445, success
# [Episode   831]  total reward: -100.835104445, success
# [Episode   832]  total reward: -88.835104445, success
# [Episode   833]  total reward: -76.835104445, success
# [Episode   834]  total reward: 17.164895555, success
# [Episode   835]  total reward: 95.164895555, success
# [Episode   836]  total reward: -70.835104445, success
# [Episode   837]  total reward: -46.835104445, success
# [Episode   838]  total reward: -112.835104445, success
# [Episode   839]  total reward: -100.835104445, success
# [Episode   840]  total reward: -76.835104445, success
# [Episode   841]  total reward: 83.164895555, success
# [Episode   842]  total reward: -76.835104445, success
# [Episode   843]  total reward: -76.835104445, success
# [Episode   844]  total reward: -88.835104445, success
# [Episode   845]  total reward: -70.835104445, success
# [Episode   846]  total reward: -82.835104445, success
# [Episode   847]  total reward: -190.835104445, success
# [Episode   848]  total reward: -102.780808811, success
# [Episode   849]  total reward: 59.164895555, success
# [Episode   850]  total reward: -70.835104445, success
# [Episode   851]  total reward: -94.835104445, success
# [Episode   852]  total reward: -160.835104445, success
# [Episode   853]  total reward: -148.835104445, success
# [Episode   854]  total reward: 71.164895555, success
# [Episode   855]  total reward: -88.835104445, success
# [Episode   856]  total reward: -88.835104445, success
# [Episode   857]  total reward: -88.835104445, success
# [Episode   858]  total reward: -82.835104445, success
# [Episode   859]  total reward: -64.835104445, success
# [Episode   860]  total reward: -88.835104445, success
# [Episode   861]  total reward: -34.835104445, success
# [Episode   862]  total reward: -148.835104445, success
# [Episode   863]  total reward: -88.835104445, success
# [Episode   864]  total reward: 35.164895555, success
# [Episode   865]  total reward: -88.835104445, success
# [Episode   866]  total reward: -136.835104445, success
# [Episode   867]  total reward: -94.835104445, success
# [Episode   868]  total reward: -88.835104445, success
# [Episode   869]  total reward: 59.164895555, success
# [Episode   870]  total reward: -184.835104445, success
# [Episode   871]  total reward: 29.164895555, success
# [Episode   872]  total reward: -88.835104445, success
# [Episode   873]  total reward: -88.835104445, success
# ...
# [Episode  9707]  total reward: 77.164895555, success
# [Episode  9708]  total reward: -34.835104445, success
# [Episode  9709]  total reward: -826.835104445, success
# [Episode  9710]  total reward: -76.835104445, success
# [Episode  9711]  total reward: -64.835104445, success
# [Episode  9712]  total reward: 29.164895555, success
# [Episode  9713]  total reward: -88.835104445, success
# [Episode  9714]  total reward: -64.835104445, success
# [Episode  9715]  total reward: -82.835104445, success
# [Episode  9716]  total reward: 35.164895555, success
# [Episode  9717]  total reward: 83.164895555, success
# [Episode  9718]  total reward: -40.835104445, success
# [Episode  9719]  total reward: -94.835104445, success
# [Episode  9720]  total reward: -512.835104445, success
# [Episode  9721]  total reward: -214.835104445, success
# [Episode  9722]  total reward: -76.835104445, success
# [Episode  9723]  total reward: -112.835104445, success
# [Episode  9724]  total reward: -76.835104445, success
# [Episode  9725]  total reward: -76.835104445, success
# [Episode  9726]  total reward: -70.835104445, success
# [Episode  9727]  total reward: -70.835104445, success
# [Episode  9728]  total reward: -220.835104445, success
# [Episode  9729]  total reward: -264.835104445, failure
# [Episode  9730]  total reward: -202.835104445, failure
# [Episode  9731]  total reward: -214.835104445, success
# [Episode  9732]  total reward: -142.835104445, success
# [Episode  9733]  total reward: 5.16489555504, success
# [Episode  9734]  total reward: -490.835104445, success
# [Episode  9735]  total reward: -418.835104445, success
# [Episode  9736]  total reward: -88.835104445, success
# [Episode  9737]  total reward: -82.835104445, success
# [Episode  9738]  total reward: -1570.83510444, success
# [Episode  9739]  total reward: -96.835104445, success
# [Episode  9740]  total reward: -88.835104445, success
# [Episode  9741]  total reward: -580.835104445, failure
# [Episode  9742]  total reward: -1762.83510444, failure
# [Episode  9743]  total reward: -958.835104445, success
# [Episode  9744]  total reward: -442.835104445, success
# [Episode  9745]  total reward: -1234.83510444, success
# [Episode  9746]  total reward: -1762.83510444, failure
# [Episode  9747]  total reward: -1750.83510444, failure
# [Episode  9748]  total reward: -250.835104445, success
# [Episode  9749]  total reward: -1762.83510444, failure
# [Episode  9750]  total reward: -1444.83510444, success
# [Episode  9751]  total reward: -1432.83510444, success
# [Episode  9752]  total reward: -1762.83510444, failure
# [Episode  9753]  total reward: -1750.83510444, failure
# [Episode  9754]  total reward: -1762.83510444, failure
# [Episode  9755]  total reward: -1762.83510444, failure
# [Episode  9756]  total reward: -640.835104445, success
# [Episode  9757]  total reward: 71.164895555, success
# [Episode  9758]  total reward: -1342.83510444, failure
# [Episode  9759]  total reward: -1160.83510444, failure
# [Episode  9760]  total reward: -1594.83510444, failure
# [Episode  9761]  total reward: -1534.83510444, failure
# [Episode  9762]  total reward: -1066.83510444, failure
# [Episode  9763]  total reward: -1734.78080881, failure
# [Episode  9764]  total reward: -1750.83510444, failure
# [Episode  9765]  total reward: -82.835104445, success
# [Episode  9766]  total reward: -1408.83510444, failure
# [Episode  9767]  total reward: -1204.83510444, failure
# [Episode  9768]  total reward: -1744.83510444, failure
# [Episode  9769]  total reward: -88.835104445, success
# [Episode  9770]  total reward: -58.835104445, success
# [Episode  9771]  total reward: -70.835104445, success
# [Episode  9772]  total reward: -1042.83510444, failure
# [Episode  9773]  total reward: -130.835104445, failure
# [Episode  9774]  total reward: -1114.83510444, failure
# [Episode  9775]  total reward: -670.835104445, success
# [Episode  9776]  total reward: -1684.83510444, failure
# [Episode  9777]  total reward: -1072.83510444, failure
# [Episode  9778]  total reward: -1222.83510444, success
# [Episode  9779]  total reward: -238.835104445, success
# [Episode  9780]  total reward: -412.835104445, success
# [Episode  9781]  total reward: -100.835104445, success
# [Episode  9782]  total reward: -1786.83510444, failure
# [Episode  9783]  total reward: -1258.83510444, success
# [Episode  9784]  total reward: -82.835104445, success
# [Episode  9785]  total reward: -748.835104445, success
# [Episode  9786]  total reward: -370.835104445, success
# [Episode  9787]  total reward: -94.835104445, success
# [Episode  9788]  total reward: -88.835104445, success
# [Episode  9789]  total reward: -82.835104445, success
# [Episode  9790]  total reward: -118.835104445, success
# [Episode  9791]  total reward: -190.835104445, success
# [Episode  9792]  total reward: -94.835104445, success
# [Episode  9793]  total reward: -454.835104445, success
# [Episode  9794]  total reward: -190.835104445, success
# [Episode  9795]  total reward: -82.835104445, success
# [Episode  9796]  total reward: -106.835104445, success
# [Episode  9797]  total reward: -142.835104445, success
# [Episode  9798]  total reward: -82.835104445, success
# [Episode  9799]  total reward: -88.835104445, success
# [Episode  9800]  total reward: -94.835104445, success
# [Episode  9801]  total reward: -82.835104445, success
# [Episode  9802]  total reward: -88.835104445, success
# [Episode  9803]  total reward: -1014.78080881, failure
# [Episode  9804]  total reward: -88.835104445, success
# [Episode  9805]  total reward: -82.835104445, success
# [Episode  9806]  total reward: -94.835104445, success
# [Episode  9807]  total reward: -82.835104445, success
# [Episode  9808]  total reward: -286.835104445, success
# [Episode  9809]  total reward: -82.835104445, success
# [Episode  9810]  total reward: -214.835104445, success
# [Episode  9811]  total reward: -1150.83510444, failure
# [Episode  9812]  total reward: -508.835104445, success
# [Episode  9813]  total reward: -76.835104445, success
# [Episode  9814]  total reward: 59.164895555, success
# [Episode  9815]  total reward: 71.164895555, success
# [Episode  9816]  total reward: -82.835104445, success
# [Episode  9817]  total reward: -82.835104445, success
# [Episode  9818]  total reward: -82.835104445, success
# [Episode  9819]  total reward: -412.835104445, success
# [Episode  9820]  total reward: -1144.83510444, failure
# [Episode  9821]  total reward: -748.835104445, failure
# [Episode  9822]  total reward: 41.164895555, success
# [Episode  9823]  total reward: -172.835104445, success
# [Episode  9824]  total reward: -700.835104445, failure
# [Episode  9825]  total reward: -1762.83510444, failure
# [Episode  9826]  total reward: -1522.83510444, failure
# [Episode  9827]  total reward: -58.835104445, success
# [Episode  9828]  total reward: -1060.83510444, success
# [Episode  9829]  total reward: -280.835104445, success
# [Episode  9830]  total reward: -76.835104445, success
# [Episode  9831]  total reward: -1276.83510444, success
# [Episode  9832]  total reward: -496.835104445, success
# [Episode  9833]  total reward: -58.835104445, success
# [Episode  9834]  total reward: -46.835104445, success
# [Episode  9835]  total reward: -46.835104445, success
# [Episode  9836]  total reward: -34.835104445, success
# [Episode  9837]  total reward: -868.835104445, success
# [Episode  9838]  total reward: -1560.83510444, failure
# [Episode  9839]  total reward: -364.835104445, success
# [Episode  9840]  total reward: -256.835104445, success
# [Episode  9841]  total reward: -1498.83510444, failure
# [Episode  9842]  total reward: 71.164895555, success
# [Episode  9843]  total reward: 71.164895555, success
# [Episode  9844]  total reward: -94.835104445, success
# [Episode  9845]  total reward: -106.835104445, success
# [Episode  9846]  total reward: -1276.83510444, success
# [Episode  9847]  total reward: -148.835104445, success
# [Episode  9848]  total reward: -244.835104445, success
# [Episode  9849]  total reward: -82.835104445, success
# [Episode  9850]  total reward: -82.835104445, success
# [Episode  9851]  total reward: -160.835104445, success
# [Episode  9852]  total reward: -118.835104445, success
# [Episode  9853]  total reward: -856.835104445, success
# [Episode  9854]  total reward: -70.835104445, success
# [Episode  9855]  total reward: -82.835104445, success
# [Episode  9856]  total reward: -124.835104445, success
# [Episode  9857]  total reward: -82.835104445, success
# [Episode  9858]  total reward: -196.835104445, success
# [Episode  9859]  total reward: -94.835104445, success
# [Episode  9860]  total reward: -82.835104445, success
# [Episode  9861]  total reward: -70.835104445, success
# [Episode  9862]  total reward: -94.835104445, success
# [Episode  9863]  total reward: -238.835104445, success
# [Episode  9864]  total reward: -82.835104445, success
# [Episode  9865]  total reward: -1414.83510444, failure
# [Episode  9866]  total reward: -76.835104445, success
# [Episode  9867]  total reward: -64.835104445, success
# [Episode  9868]  total reward: -64.835104445, success
# [Episode  9869]  total reward: -976.835104445, success
# [Episode  9870]  total reward: -64.835104445, success
# [Episode  9871]  total reward: -70.835104445, success
# [Episode  9872]  total reward: -444.835104445, success
# [Episode  9873]  total reward: -610.835104445, success
# [Episode  9874]  total reward: -64.835104445, success
# [Episode  9875]  total reward: -694.835104445, failure
# [Episode  9876]  total reward: -984.835104445, success
# [Episode  9877]  total reward: -232.835104445, success
# [Episode  9878]  total reward: -100.835104445, success
# [Episode  9879]  total reward: -1360.83510444, failure
# [Episode  9880]  total reward: -82.835104445, success
# [Episode  9881]  total reward: -486.835104445, success
# [Episode  9882]  total reward: -292.835104445, success
# [Episode  9883]  total reward: -76.835104445, success
# [Episode  9884]  total reward: -130.835104445, success
# [Episode  9885]  total reward: -1168.83510444, success
# [Episode  9886]  total reward: -762.835104445, failure
# [Episode  9887]  total reward: -286.835104445, success
# [Episode  9888]  total reward: -1012.83510444, success
# [Episode  9889]  total reward: -208.835104445, success
# [Episode  9890]  total reward: -94.835104445, success
# [Episode  9891]  total reward: -1080.83510444, failure
# [Episode  9892]  total reward: -796.835104445, failure
# [Episode  9893]  total reward: -598.835104445, failure
# [Episode  9894]  total reward: -816.835104445, failure
# [Episode  9895]  total reward: -328.835104445, success
# [Episode  9896]  total reward: -1272.83510444, failure
# [Episode  9897]  total reward: -1462.83510444, failure
# [Episode  9898]  total reward: -1402.83510444, failure
# [Episode  9899]  total reward: -1072.83510444, success
# [Episode  9900]  total reward: -1060.83510444, success
# [Episode  9901]  total reward: -346.835104445, success
# [Episode  9902]  total reward: -1478.83510444, failure
# [Episode  9903]  total reward: -100.835104445, success
# [Episode  9904]  total reward: -202.835104445, success
# [Episode  9905]  total reward: -244.835104445, success
# [Episode  9906]  total reward: -490.835104445, success
# [Episode  9907]  total reward: -100.835104445, success
# [Episode  9908]  total reward: -1678.83510444, success
# [Episode  9909]  total reward: -172.835104445, success
# [Episode  9910]  total reward: -1786.83510444, failure
# [Episode  9911]  total reward: -100.835104445, success
# [Episode  9912]  total reward: -130.835104445, success
# [Episode  9913]  total reward: -214.835104445, success
# [Episode  9914]  total reward: -136.835104445, success
# [Episode  9915]  total reward: -112.835104445, success
# [Episode  9916]  total reward: -98.835104445, success
# [Episode  9917]  total reward: -56.835104445, success
# [Episode  9918]  total reward: -160.835104445, success
# [Episode  9919]  total reward: -106.835104445, success
# [Episode  9920]  total reward: -232.835104445, success
# [Episode  9921]  total reward: -100.835104445, success
# [Episode  9922]  total reward: -106.835104445, success
# [Episode  9923]  total reward: -82.835104445, success
# [Episode  9924]  total reward: -106.835104445, success
# [Episode  9925]  total reward: -250.835104445, success
# [Episode  9926]  total reward: -94.835104445, success
# [Episode  9927]  total reward: -100.835104445, success
# [Episode  9928]  total reward: -94.835104445, success
# [Episode  9929]  total reward: -106.835104445, success
# [Episode  9930]  total reward: -100.835104445, success
# [Episode  9931]  total reward: -148.835104445, success
# [Episode  9932]  total reward: -112.835104445, success
# [Episode  9933]  total reward: -112.835104445, success
# [Episode  9934]  total reward: -82.835104445, success
# [Episode  9935]  total reward: -76.835104445, success
# [Episode  9936]  total reward: -76.835104445, success
# [Episode  9937]  total reward: -76.835104445, success
# [Episode  9938]  total reward: -76.835104445, success
# [Episode  9939]  total reward: -76.835104445, success
# [Episode  9940]  total reward: -76.835104445, success
# [Episode  9941]  total reward: -82.835104445, success
# [Episode  9942]  total reward: -286.835104445, success
# [Episode  9943]  total reward: -1154.83510444, success
# [Episode  9944]  total reward: -76.835104445, success
# [Episode  9945]  total reward: -76.835104445, success
# [Episode  9946]  total reward: -154.835104445, failure
# [Episode  9947]  total reward: -94.835104445, success
# [Episode  9948]  total reward: -82.835104445, success
# [Episode  9949]  total reward: -312.835104445, failure
# [Episode  9950]  total reward: -82.835104445, success
# [Episode  9951]  total reward: -112.835104445, success
# [Episode  9952]  total reward: -100.835104445, success
# [Episode  9953]  total reward: -214.835104445, success
# [Episode  9954]  total reward: -76.835104445, success
# [Episode  9955]  total reward: -180.780808811, success
# [Episode  9956]  total reward: -82.835104445, success
# [Episode  9957]  total reward: -516.835104445, success
# [Episode  9958]  total reward: -82.835104445, success
# [Episode  9959]  total reward: -88.835104445, success
# [Episode  9960]  total reward: -82.835104445, success
# [Episode  9961]  total reward: -172.835104445, success
# [Episode  9962]  total reward: -250.835104445, success
# [Episode  9963]  total reward: -76.835104445, success
# [Episode  9964]  total reward: -82.835104445, success
# [Episode  9965]  total reward: -82.835104445, success
# [Episode  9966]  total reward: -94.835104445, success
# [Episode  9967]  total reward: -82.835104445, success
# [Episode  9968]  total reward: -142.835104445, success
# [Episode  9969]  total reward: -436.835104445, success
# [Episode  9970]  total reward: -76.835104445, success
# [Episode  9971]  total reward: -76.835104445, success
# [Episode  9972]  total reward: -136.835104445, success
# [Episode  9973]  total reward: -96.7808088114, success
# [Episode  9974]  total reward: -82.835104445, success
# [Episode  9975]  total reward: -82.835104445, success
# [Episode  9976]  total reward: -94.835104445, success
# [Episode  9977]  total reward: -88.835104445, success
# [Episode  9978]  total reward: -512.835104445, success
# [Episode  9979]  total reward: -280.835104445, success
# [Episode  9980]  total reward: -396.835104445, success
# [Episode  9981]  total reward: -94.835104445, success
# [Episode  9982]  total reward: -322.835104445, success
# [Episode  9983]  total reward: -88.835104445, success
# [Episode  9984]  total reward: -82.835104445, success
# [Episode  9985]  total reward: -100.835104445, success
# [Episode  9986]  total reward: -82.835104445, success
# [Episode  9987]  total reward: -82.835104445, success
# [Episode  9988]  total reward: -88.835104445, success
# [Episode  9989]  total reward: -88.835104445, success
# [Episode  9990]  total reward: -88.835104445, success
# [Episode  9991]  total reward: -112.835104445, success
# [Episode  9992]  total reward: -106.835104445, success
# [Episode  9993]  total reward: -88.835104445, success
# [Episode  9994]  total reward: -94.835104445, success
# [Episode  9995]  total reward: -82.835104445, success
# [Episode  9996]  total reward: -82.835104445, success
# [Episode  9997]  total reward: -100.835104445, success
# [Episode  9998]  total reward: -810.835104445, failure
# [Episode  9999]  total reward: -82.835104445, success
# 2190.31798697

# %% [markdown]
# ## DQN to cooperate 2 Mobile Manipulator
# * made by hotae
# * network includes one agent's action
# * hidden state(goal, obs1, obs2)

# %%
#Plotting setting
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import animation
from time import sleep

import numpy as np
import tensorflow as tf
import random
import dqn_cooperation
from collections import deque

import time
start = time.time()

# Create New environment with transition law
ACTION_NUM = 4
INPUT_SIZE = 4
OUTPUT_SIZE = ACTION_NUM
VEL = 0.5
TIME_GAP = 1

def annealing_epsilon(episode, min_e, max_e, target_episode):
    slope = (min_e - max_e) / (target_episode)
    intercept = max_e

    return max(min_e, slope * episode + intercept)

class new_env:     
    def create_env(self, arg_state=[0.,0.,1.0,1.0], g_pos=[5,5], obs_pos1=[2,2], obs_pos2=[3,4], obs_size=5):
        self.state = np.array(arg_state) # reset
        self.n_state = np.array(arg_state) #reset
        self.goal_pos = np.array(g_pos)
        self.obstacle_pos1 = np.array(obs_pos1)
        self.obstacle_pos2 = np.array(obs_pos2)
        self.obstacle_size = obs_size
        return self.state, self.goal_pos, self.obstacle_pos1, self.obstacle_pos2, self.obstacle_size
        
    def next_step(self, arg_state, arg_action):
        self._fail = False
        self.reward = 0
        # choose the action
        arg_action1 = arg_action 
        
        '''position update through action
        UP = 0, DOWN = 1, LEFT = 2, RIGHT = 3'''        
        # agent located on the first state 
        if arg_action1 == 0:
            mid_state = arg_state + np.array([0,1,0,0])*VEL*TIME_GAP # move the 1st agent
        elif arg_action1 == 1:
            mid_state = arg_state + np.array([0,-1,0,0])*VEL*TIME_GAP
        elif arg_action1 == 2:
            mid_state = arg_state + np.array([-1,0,0,0])*VEL*TIME_GAP
        else:
            mid_state = arg_state + np.array([1,0,0,0])*VEL*TIME_GAP
        
        self.n_state[0:2] = mid_state[2:4] # change 1 and 2
        self.n_state[2:4] = mid_state[0:2]        
       
        '''get the reward'''
        if np.linalg.norm((self.n_state[0:2]+self.n_state[2:4])/2-self.goal_pos)!=0:
            self.reward = (1/np.linalg.norm((self.n_state[0:2]+self.n_state[2:4])/2-self.goal_pos)-\
            1/np.linalg.norm((arg_state[0:2]+arg_state[2:4])/2-self.goal_pos))*30
        if np.linalg.norm(self.n_state[0:2]-self.obstacle_pos1)<1 or np.linalg.norm(self.n_state[2:4]-self.obstacle_pos1)<1:
            self.reward = -2 # collision
        if np.linalg.norm(self.n_state[0:2]-self.obstacle_pos2)<1 or np.linalg.norm(self.n_state[2:4]-self.obstacle_pos2)<1:
            self.reward = -2 # collision
        if np.linalg.norm((self.n_state[0:2]+self.n_state[2:4])/2-self.goal_pos)<1: # approximately set condition
            self.reward =  100 # achieve goal
            self._fail = True
        if np.linalg.norm(self.n_state[0:2]-self.n_state[2:4])>2.5:
            self.reward = -60 # drop the object
            self._fail = True       
        '''
        if any(x<0 for x in self.n_state):            
            self.reward = -50 # away from the map
            self._fail = True   
        if any(x>7 for x in self.n_state):            
            self.reward = -80 # away from the map
            self._fail = True 
        '''
        return self.n_state, self.reward, self._fail
    
#env = new_env() 
#state, g_pos, o_pos, o_size = env.create_env() # set the enviornment
DISCOUNT_RATE = 0.98
REPLAY_MEMORY = 10000
BATCH_SIZE = 50
MAX_EPI = 120000

# minimum epsilon for epsilon greedy
MIN_E = 0.0
# epsilon will be `MIN_E` at `EPSILON_DECAYING_EPISODE`
EPSILON_DECAYING_EPISODE = MAX_EPI * 0.5

def train_minibatch(DQN, minibatch):
    state_array = np.array([x[0] for x in minibatch])
    action_array = np.array([x[1] for x in minibatch]) # [ x among 0~3] * BATCH_SIZE
    reward_array = np.array([x[2] for x in minibatch])
    n_state_array = np.array([x[3] for x in minibatch])
    _fail_array = np.array([x[4] for x in minibatch])    
    
    X_batch = state_array   
    Y_batch = DQN.predict(state_array) # 4 elements * BATCH_SIZE 
    Q_target = reward_array + DISCOUNT_RATE*np.max(DQN.predict(n_state_array),axis=1)*~_fail_array # if fail, Q = reward
    
    Y_batch[np.arange(len(X_batch)), action_array] = Q_target
    
    # Train
    cost_batch, _ = DQN.update(X_batch, Y_batch)
    return cost_batch

def main():
    replay_buffer = deque(maxlen=REPLAY_MEMORY) # detract element from both sides    
    
    with tf.Session() as sess:
        mainDQN = dqn_cooperation.DQN(sess, INPUT_SIZE, OUTPUT_SIZE)
        mainDQN.build_network(8,32,0.002)
        init = tf.global_variables_initializer()
        sess.run(init)
        reward_accum_last100 = 0
        reward_sum = 0
        '''
        #set list for drawing graph
        arrX = []
        arrY = []
        # draw the graph
        fig = plt.figure()
        ax = plt.axes(xlim=(0,1000), ylim=(-50,100))
        '''
        MAP_SIZE = 7
        game = ENV(MAP_SIZE, [2,2], [3,4], [0,0,1,1], [5,5]) # __init__(self, map_size, obs_pos1, obs_pos2, robot_start_pos, goal_pos):
        game.render_env()
        
        for episode in range(MAX_EPI):
            e = annealing_epsilon(episode, MIN_E, 1.0, EPSILON_DECAYING_EPISODE)
            _fail = False
            count = 0 # how many moves included in an episode
            env1 = new_env()
            state, _, _, _, _= env1.create_env() # get only state, return self.state, self.goal_pos, self.obstacle_pos1, self.obstacle_pos2, self.obstacle_size
            if episode >MAX_EPI-100:
                reward_accum_last100 += reward_sum # to calculate success ratio, accumulate reward_sum
                                    
            '''
            # draw the graph lively
            x = episode
            y = reward_sum
            arrX.append(x)
            arrY.append(y)
            a= plt.plot(arrX,arrY,'g')
            fig.canvas.draw()    
            sleep(0.2)
            #a.remove()
            '''
            reward_sum = 0            
            while not _fail:
                # after sufficient learning, we present the game scene
                if episode >MAX_EPI-20:
                    game.update(state)
                    game.render_env()
                    
                count += 1
                # apply constraint about walls                   
                if np.random.rand()< e:
                    act_candi = range(ACTION_NUM)
                    if state[0]<TIME_GAP*VEL:
                        act_candi.remove(2) # remove action 2(left)
                    if state[1]<TIME_GAP*VEL:
                        act_candi.remove(1) # remove action 1(down)
                    if state[0] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi.remove(3) # remove action 3(right)
                    if state[1] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi.remove(0) # remove action 0(up)    
                    act_candi1 = np.array(act_candi)
                    action_l = random.sample(act_candi1,1) # choose upL, down, left, right 
                    action = action_l[0]
                else:  
                    act_candi = mainDQN.predict(state)
                    act_candi = act_candi.flatten()
                    
                    if state[0]<TIME_GAP*VEL:
                        act_candi[2] = -1000 # put a large num on action 2(left)
                    if state[1]<TIME_GAP*VEL:
                        act_candi[1] = -1000 # put a large num on action 1(down)
                    if state[0] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi[3] = -1000 # remove action 3(right)
                    if state[1] > MAP_SIZE - TIME_GAP*VEL:
                        act_candi[0] = -1000 # remove action 0(up)    
                    action = np.argmax(act_candi)   
                    '''
                    dd_predict = mainDQN.predict(state).flatten()
                    aa = np.max(dd_predict)
                    max_indx, = np.where(dd_predict==aa)                    
                    action = random.sample(max_indx,1)[0]
                    '''
                n_state, reward, _fail = env1.next_step(state, action) # have to input the action 
                # if count >30, stop that episode and start new episode, counted every time one agent moves
                if count >40:
                    reward = -30
                    _fail = True
                    
                reward_sum += reward    # sum total reward and penalty about long time(-0.5)          
                replay_buffer.append((state, action, reward, n_state, _fail)) #resolve the correlation
                
                state = n_state
                           
                if len(replay_buffer)>BATCH_SIZE:
                    minibatch = random.sample(replay_buffer, BATCH_SIZE)                    
                    train_minibatch(mainDQN, minibatch)
            
            print("[Episode {:>5}]  total reward: {:>5}".format(episode, reward_sum))
    print("Success ratio: {}".format(reward_accum_last100/100))
    
        
if __name__ == "__main__":
    main()    
    end = time.time()-start
    print(end)
